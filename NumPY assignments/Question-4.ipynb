# %% [markdown]
# ## Create a 10x10 array with random values and find the minimum and maximum values.

# %%
import numpy as np

Array = np.random.random((10,10))
Min=np.min(Array)
Max=np.max(Array)

print("Array-",Array)
print("\nMinimum number of aaray-",Min)
print("\nMaximum number of aaray-",Max)
# Out:
# Array- [[0.15455842 0.16877451 0.07392583 0.46944287 0.66234585 0.00809856
#   0.41756669 0.17304136 0.04048465 0.09707968]
#  [0.95124101 0.11782141 0.72257314 0.8505276  0.92152187 0.96781219
#   0.88626291 0.74587228 0.65371742 0.65283849]
#  [0.37601537 0.94864494 0.40767661 0.75129856 0.17333531 0.72448588
#   0.09510367 0.08119143 0.14483802 0.27803724]
#  [0.69348912 0.89901659 0.72370813 0.71490777 0.94426573 0.25050905
#   0.3231919  0.32175874 0.54369087 0.96834431]
#  [0.46799226 0.46284032 0.35783911 0.42845661 0.18135536 0.32397178
#   0.50385332 0.33534327 0.14526057 0.30131587]
#  [0.8598371  0.01897966 0.91100467 0.42983116 0.59686099 0.64449111
#   0.85568785 0.67617886 0.85802352 0.39443221]
#  [0.2533163  0.8684642  0.89802722 0.28034104 0.07935886 0.29627528
#   0.78532027 0.87273764 0.34990883 0.06084013]
#  [0.84028949 0.74325834 0.46101497 0.372602   0.51540006 0.99088213
#   0.91932037 0.2629296  0.58318772 0.24577655]
# ...
